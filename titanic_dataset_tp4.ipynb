# %% [markdown]
# # TP4 Individuelle (titanic dataset)
#
# > Ajouter une citation

# %% [markdown]
# ### Charger le dataset Titanic avec Pandas et afficher les 10 premières lignes

# %%
import pandas as pd

# Charger le dataset (adapter le chemin si nécessaire)
df = pd.read_csv("titanic.csv")

# Afficher les 10 premières lignes
print(df.head(10))

# Dimensions du dataset
print(df.shape)

# Informations générales
print(df.info())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### Calculer les statistiques descriptives et grouper par classe et sexe

# %%
# Statistiques descriptives globales
print(df.describe())

# Taux de survie par classe (Pclass)
print(df.groupby('Pclass')['Survived'].mean())

# Taux de survie par sexe
print(df.groupby('Sex')['Survived'].mean())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# ...

# %% [markdown]
# ### Identifier et traiter toutes les valeurs manquantes

# %%
# Vérifier les valeurs manquantes
print(df.isnull().sum())

# Remplacer Age par la médiane
df['Age'] = df['Age'].fillna(df['Age'].median())

# Remplacer Embarked par le mode (valeur la plus fréquente)
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Vérification après nettoyage
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64
